# %%
from normalize import normalize_feature_table, build_cross_chain_address_summary

df_norm = normalize_feature_table(df_features)
df_summary = build_cross_chain_address_summary(df_norm)

df_norm.head()
df_summary.head()

# %%
from classify import classify_from_normalized_df, behavioral_group_counts

df_classified = classify_from_normalized_df(df_norm)

df_classified.head()
behavioral_group_counts(df_classified)
