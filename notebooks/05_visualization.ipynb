# %%
from plots import (
    PlotConfig,
    plot_overlap_heatmap,
    plot_jaccard_heatmap,
    plot_behavioral_group_distribution,
    plot_dominant_chain_distribution,
    plot_transition_heatmap,
    plot_activity_score_boxplot,
    plot_recency_histogram,
    save_figure,
)

plot_cfg = PlotConfig()

fig, ax = plot_overlap_heatmap(df_norm, min_total_tx=3)
save_figure(fig, "outputs/figures/overlap_heatmap.png", plot_cfg)

fig, ax = plot_jaccard_heatmap(df_norm, min_total_tx=3)
save_figure(fig, "outputs/figures/jaccard_heatmap.png", plot_cfg)

fig, ax = plot_behavioral_group_distribution(df_classified)
save_figure(fig, "outputs/figures/behavioral_group_distribution.png", plot_cfg)

fig, ax = plot_dominant_chain_distribution(df_classified)
save_figure(fig, "outputs/figures/dominant_chain_distribution.png", plot_cfg)

fig, ax = plot_transition_heatmap(df_classified, only_migrators=False)
save_figure(fig, "outputs/figures/transition_heatmap.png", plot_cfg)

fig, ax = plot_activity_score_boxplot(df_norm)
save_figure(fig, "outputs/figures/activity_score_boxplot.png", plot_cfg)

fig, ax = plot_recency_histogram(df_norm)
save_figure(fig, "outputs/figures/recency_histogram.png", plot_cfg)
